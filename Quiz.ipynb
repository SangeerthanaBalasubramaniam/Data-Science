# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasets/hepatitis/master/data/hepatitis.csv")

# %%
df.head()
# Out:
#    age     sex steroid  antivirals  ... albumin protime histology class
# 0   30    male   False       False  ...     4.0     NaN     False  live
# 1   50  female   False       False  ...     3.5     NaN     False  live
# 2   78  female    True       False  ...     4.0     NaN     False  live
# 3   31  female     NaN        True  ...     4.0    80.0     False  live
# 4   34  female    True       False  ...     4.0     NaN     False  live
#
# [5 rows x 20 columns]

# %%
df["sgot"].var()
# Out:
# 8037.282030905076

# %%
df1 = df.copy()

# %%
df1.fillna(df["sgot"].median())
# Out:
#      age     sex steroid  antivirals  ... albumin protime histology class
# 0     30    male   False       False  ...     4.0    58.0     False  live
# 1     50  female   False       False  ...     3.5    58.0     False  live
# 2     78  female    True       False  ...     4.0    58.0     False  live
# 3     31  female      58        True  ...     4.0    80.0     False  live
# 4     34  female    True       False  ...     4.0    58.0     False  live
# ..   ...     ...     ...         ...  ...     ...     ...       ...   ...
# 150   46  female    True       False  ...     3.3    50.0      True   die
# 151   44  female    True       False  ...     4.3    58.0      True  live
# 152   61  female   False       False  ...     4.1    58.0      True  live
# 153   53    male   False       False  ...     4.1    48.0      True  live
# 154   43  female    True       False  ...     3.1    42.0      True   die
#
# [155 rows x 20 columns]

# %%
df1.var()
# Out:
# age                 157.901299
# steroid               0.251592
# antivirals            0.131713
# fatigue               0.229183
# malaise               0.240769
# anorexia              0.165691
# liver_big             0.143678
# liver_firm            0.244755
# spleen_palpable       0.161074
# spiders               0.225906
# ascites               0.116331
# varices               0.106309
# bilirubin             1.469305
# alk_phosphate      2653.085270
# sgot               8037.282031
# albumin               0.424482
# protime             523.276776
# histology             0.249267
# dtype: float64

# %%
df2 = df.copy()

# %%
df.fillna(df["sgot"].mean())
# Out:
#      age     sex steroid  antivirals  ... albumin   protime histology class
# 0     30    male   False       False  ...     4.0  85.89404     False  live
# 1     50  female   False       False  ...     3.5  85.89404     False  live
# 2     78  female    True       False  ...     4.0  85.89404     False  live
# 3     31  female  85.894        True  ...     4.0  80.00000     False  live
# 4     34  female    True       False  ...     4.0  85.89404     False  live
# ..   ...     ...     ...         ...  ...     ...       ...       ...   ...
# 150   46  female    True       False  ...     3.3  50.00000      True   die
# 151   44  female    True       False  ...     4.3  85.89404      True  live
# 152   61  female   False       False  ...     4.1  85.89404      True  live
# 153   53    male   False       False  ...     4.1  48.00000      True  live
# 154   43  female    True       False  ...     3.1  42.00000      True   die
#
# [155 rows x 20 columns]

# %%
df2.var()
# Out:
# age                 157.901299
# steroid               0.251592
# antivirals            0.131713
# fatigue               0.229183
# malaise               0.240769
# anorexia              0.165691
# liver_big             0.143678
# liver_firm            0.244755
# spleen_palpable       0.161074
# spiders               0.225906
# ascites               0.116331
# varices               0.106309
# bilirubin             1.469305
# alk_phosphate      2653.085270
# sgot               8037.282031
# albumin               0.424482
# protime             523.276776
# histology             0.249267
# dtype: float64

# %%
dff = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data")

# %%
dff.head()
# Out:
#    39          State-gov   77516   Bachelors  ...   0  40   United-States   <=50K
# 0  50   Self-emp-not-inc   83311   Bachelors  ...   0  13   United-States   <=50K
# 1  38            Private  215646     HS-grad  ...   0  40   United-States   <=50K
# 2  53            Private  234721        11th  ...   0  40   United-States   <=50K
# 3  28            Private  338409   Bachelors  ...   0  40            Cuba   <=50K
# 4  37            Private  284582     Masters  ...   0  40   United-States   <=50K
#
# [5 rows x 15 columns]

# %%
ml_age = dff.copy()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Identify wrong one

# %%
ml_age.hist(normed=0, histtype='stepfilled', alpha=.5, color=sns.desaturate(&quot;indianred&quot;, .75), bins=10)
# Out:
#   File "<ipython-input-15-4fdc32d80295>", line 1
#     ml_age.hist(normed=0, histtype='stepfilled', alpha=.5, color=sns.desaturate(&quot;indianred&quot;, .75), bins=10)
#                                                                                 ^
# SyntaxError: invalid syntax

# %%
ml_age.hist(normed=1, histtype='stepfilled', bins=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-9fa300050b6f> in <module>()
# ----> 1 ml_age.hist(normed=1, histtype='stepfilled', bins=20)
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     225         legend=legend,
#     226         bins=bins,
# --> 227         **kwargs,
#     228     )
#     229
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     432         if legend and can_set_label:
#     433             kwds["label"] = col
# --> 434         ax.hist(data[col].dropna().values, bins=bins, **kwds)
# ...

# %%
ml_age.hist(normed=0, histtype='stepfilled', bins=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-77740eaa3d34> in <module>()
# ----> 1 ml_age.hist(normed=0, histtype='stepfilled', bins=20)
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     225         legend=legend,
#     226         bins=bins,
# --> 227         **kwargs,
#     228     )
#     229
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     432         if legend and can_set_label:
#     433             kwds["label"] = col
# --> 434         ax.hist(data[col].dropna().values, bins=bins, **kwds)
# ...

# %%
df = pd.read_csv("/content/fires.csv")

# %%
df.head()
# Out:
#    Year State    Month  Number of Fires Date Reported
# 0  1998  Acre  January              0.0     1/01/1998
# 1  1999  Acre  January              0.0     1/01/1999
# 2  2000  Acre  January              0.0     1/01/2000
# 3  2001  Acre  January              0.0     1/01/2001
# 4  2002  Acre  January              0.0     1/01/2002

# %%
df["Number of Fires"].max()
# Out:
# 998.0

# %%
df["State"].nunique()
# Out:
# 27

# %%
df["State"].value_counts()
# Out:
# Alagoas                240
# Tocantins              239
# Amapá                  239
# Pará                   239
# Mato Grosso do Sul     239
# Rio Grande do Norte    239
# Goiás                  239
# Minas Gerais           239
# Mato Grosso            239
# Paraná                 239
# Amazonas               239
# Rio Grande do Sul      239
# Ceará                  239
# Paraíba                239
# Rio de January         239
# São Paulo              239
# Roraima                239
# Distrito Federal       239
# Sergipe                239
# Pernambuco             239
# Santa Catarina         239
# Acre                   239
# Espírito Santo         239
# Rondônia               239
# Bahia                  239
# Piauí                  239
# Maranhão               239
# Name: State, dtype: int64

# %%
df = pd.read_csv("https://raw.githubusercontent.com/DeepikaTG/Dataset/main/CGM.csv")
df.head()
# Out:
#     isig             datetime  glucose
# 0  22.59  2010-03-24 09:51:00      258
# 1  22.52  2010-03-24 09:56:00      260
# 2  22.23  2010-03-24 10:01:00      258
# 3  21.56  2010-03-24 10:06:00      254
# 4  20.79  2010-03-24 10:11:00      246

# %%
df['glucose'].quantile([0.25,0.5,0.75])
# Out:
# 0.25     99.0
# 0.50    126.0
# 0.75    163.0
# Name: glucose, dtype: float64
